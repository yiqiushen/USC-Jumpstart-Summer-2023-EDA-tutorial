# %% [markdown]
# # Introduction to Data Wrangling and Explanatory Data Analysis (EDA)
#
# This original tutorial is written by Yiqiu Shen (yiqiushe@usc.edu) for the USC JumpStart Summer Program 2023 at the Department of Data Sciences and Operations, Marshall School of Business. Should you have any questions, feel free to contact me.
#
# ## Data Wrangling

# %% [markdown]
# The datasets we will use are: https://www.kaggle.com/datasets/rojour/boston-results.  These are lists of the finishers of the Boston Marathon of 2015, 2016 and 2017 respectively, and contain the name, age, gender, country, city and state (where available), times at 9 different stages of the race, expected time, finish time and pace, overall place, gender place and division place.

# %% [markdown]
# ### Load the datasets, aggregate the datasets

# %%
import pandas as pd
import numpy as np

data_2015 = pd.read_csv("./marathon_results_2015.csv")
data_2016 = pd.read_csv("./marathon_results_2016.csv")
data_2017 = pd.read_csv("./marathon_results_2017.csv")

# Add a new column 'Year' with the corresponding year for each dataframe
data_2015['Year'] = 2015
data_2016['Year'] = 2016
data_2017['Year'] = 2017

# Concatenate the three dataframes into a single dataframe 'df'
df = pd.concat([data_2015, data_2016, data_2017], ignore_index=True)

# %% [markdown]
# ### Inspect the dataset
#
# First, let us inspect some entries from the dataframe to get a rough impression. We can start with the first entries:

# %%
df.head()
# Out:
#    Unnamed: 0 Bib                   Name  Age M/F         City State Country  \
# 0         0.0   3         Desisa, Lelisa   25   M         Ambo   NaN     ETH
# 1         1.0   4  Tsegay, Yemane Adhane   30   M  Addis Ababa   NaN     ETH
# 2         2.0   8         Chebet, Wilson   29   M     Marakwet   NaN     KEN
# 3         3.0  11       Kipyego, Bernard   28   M      Eldoret   NaN     KEN
# 4         4.0  10          Korir, Wesley   32   M       Kitale   NaN     KEN
#
#   Citizen Unnamed: 9  ...      35K      40K     Pace Proj Time Official Time  \
# 0     NaN        NaN  ...  1:47:59  2:02:39  0:04:56         -       2:09:17
# 1     NaN        NaN  ...  1:47:59  2:02:42  0:04:58         -       2:09:48
# 2     NaN        NaN  ...  1:47:59  2:03:01  0:04:59         -       2:10:22
# 3     NaN        NaN  ...  1:48:03  2:03:47  0:05:00         -       2:10:47
# 4     NaN        NaN  ...  1:47:59  2:03:27  0:05:00         -       2:10:49
#
#   Overall Gender Division  Year Unnamed: 8
# 0       1      1        1  2015        NaN
# 1       2      2        2  2015        NaN
# 2       3      3        3  2015        NaN
# 3       4      4        4  2015        NaN
# 4       5      5        5  2015        NaN
#
# [5 rows x 27 columns]

# %% [markdown]
# Or the last entries:

# %%
df.tail()
# Out:
#        Unnamed: 0    Bib                      Name  Age M/F          City  \
# 79633     26405.0  25166  Steinbach, Paula Eyvonne   61   F       Ontario
# 79634     26406.0  25178        Avelino, Andrew R.   25   M  Fayetteville
# 79635     26407.0  27086           Hantel, Johanna   57   F       Malvern
# 79636     26408.0  25268              Reilly, Bill   64   M      New York
# 79637     26409.0  25266             Rigsby, Scott   48   M    Alpharetta
#
#       State Country Citizen Unnamed: 9  ...      35K      40K     Pace  \
# 79633    CA     USA     NaN         MI  ...  5:55:18  6:46:57  0:16:24
# 79634    NC     USA     NaN         MI  ...  5:53:48  6:54:21  0:16:40
# 79635    PA     USA     NaN        NaN  ...  6:00:33  6:54:38  0:16:47
# 79636    NY     USA     NaN         MI  ...  6:06:07  6:56:08  0:16:49
# 79637    GA     USA     NaN         MI  ...  6:39:07  7:41:23  0:18:15
#
#       Proj Time Official Time Overall Gender Division  Year Unnamed: 8
# 79633         -       7:09:39   26407  11972      344  2017        NaN
# 79634         -       7:16:59   26408  14436     4774  2017        NaN
# 79635         -       7:19:37   26409  11973      698  2017        NaN
# 79636         -       7:20:44   26410  14437     1043  2017        NaN
# 79637         -       7:58:14   26411  14438     2553  2017        NaN
#
# [5 rows x 27 columns]

# %% [markdown]
# Or even some random entries:

# %%
df.sample(10)
# Default sample is executed without replacement. If you want to sample with replacement, use
# df.sample(replace=True)
# Out:
#        Unnamed: 0    Bib                   Name  Age M/F          City State  \
# 4115       4115.0   6534   Boulanger, Simon Sr.   35   M    Terrebonne    QC
# 54244      1016.0    650              Zhang, Yu   33   M     Sunnyvale    CA
# 25369     25369.0  30261   Clifford, Kaitlyn A.   32   F  South Boston    MA
# 3219       3219.0   4077             West, John   53   M       Alameda    CA
# 38552         NaN  20486      Handyside, Leslie   41   F    Northville    MI
# 1108       1108.0   1142       Cherewatti, Jack   28   M    Somerville    MA
# 19894     19894.0  31555  Bhathal, Alexander S.   39   M  Laguna Beach    CA
# 75851     22623.0  13796       Burwell, Julie A   36   F   East Peoria    IL
# 69216     15988.0  19251      Taylor, Andrea C.   43   F      Oakville    ON
# 76169     22941.0  20848     Rigitano, Vincenzo   63   M  Stoney Creek    ON
#
#       Country Citizen Unnamed: 9  ...      35K      40K     Pace Proj Time  \
# 4115      CAN     NaN        NaN  ...  2:32:40  2:56:55  0:07:10         -
# 54244     USA     CHN        NaN  ...  2:23:37  2:46:11  0:06:44         -
# 25369     USA     NaN        NaN  ...  4:14:29  4:55:07  0:11:54         -
# 3219      USA     NaN        NaN  ...  2:30:11  2:52:37  0:06:59         -
# 38552     USA     NaN        NaN  ...  3:05:48  3:32:36  0:08:32   3:43:38
# 1108      USA     NaN        NaN  ...  2:21:49  2:42:33  0:06:33         -
# 19894     USA     NaN        NaN  ...  3:21:20  3:52:43  0:09:24         -
# 75851     USA     NaN        NaN  ...  3:51:57  4:28:56  0:10:52         -
# 69216     CAN     NaN        NaN  ...  3:19:14  3:48:42  0:09:14         -
# 76169     CAN     NaN        NaN  ...  3:50:32  4:30:47  0:10:59         -
#
#       Official Time Overall Gender Division  Year Unnamed: 8
# 4115        3:07:34    4116   3801     2578  2015        NaN
# 54244       2:56:19    1017    960      750  2017        NaN
# 25369       5:11:38   25370  11326     5635  2015        NaN
# 3219        3:02:57    3220   3025      109  2015        NaN
# 38552       3:43:38   11954   3778      626  2016        NaN
# 1108        2:51:39    1109   1063      887  2015        NaN
# 19894       4:06:02   19895  11704     4188  2015        NaN
# 75851       4:44:42   22625   9874     4872  2017        NaN
# 69216       4:01:43   15990   6099     1066  2017        NaN
# 76169       4:47:50   22943  12894      863  2017        NaN
#
# [10 rows x 27 columns]

# %% [markdown]
# Check the number of rows, columns:

# %%
df.shape
# Out:
# (79638, 27)

# %% [markdown]
# Check type of each column:

# %%
df.dtypes
# Out:
# Unnamed: 0       float64
# Bib               object
# Name              object
# Age                int64
# M/F               object
# City              object
# State             object
# Country           object
# Citizen           object
# Unnamed: 9        object
# 5K                object
# 10K               object
# 15K               object
# 20K               object
# Half              object
# 25K               object
# 30K               object
# 35K               object
# 40K               object
# Pace              object
# Proj Time         object
# Official Time     object
# Overall            int64
# Gender             int64
# Division           int64
# Year               int64
# Unnamed: 8        object
# dtype: object

# %% [markdown]
# We can see that all columns relating to time are not of type numeric, which needs further processing.
#
# But let us finish inspecting first. Let's check if there are duplicates.

# %%
print("Number of duplicate rows: ", df.duplicated().sum())
# Out:
# Number of duplicate rows:  0

# %% [markdown]
# Since there are no duplicates, we will randomly duplicate 10 rows and add them to the end of the original data frame for demonstration purpose.

# %%
df = pd.concat([df, df.sample(n=10)])
print('Number of duplicate rows after tampering: ', df.duplicated().sum())
# Out:
# Number of duplicate rows after tampering:  10

# %% [markdown]
# Then we can remove the duplicating rows:

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# `df=df.drop_duplicates()` also works to remove the duplicating rows.
#
# Note: If we want to modify a dataframe without creating a new one, most dataframe operations support inplace argument. If we simply use `df.drop_duplicates()`, this will create a new copy of modified dataFrame.

# %% [markdown]
# ### Transforming Data
#
# Previously, we mentioned that the format of time is not desirable. We want to change its type from object to numeric. One way to do is to convert to seconds using `pd.to_timedelta()` method. Let's take the 5K column as an example.

# %%
temp_5k_in_seconds = pd.to_timedelta(df['5K'], errors='coerce').dt.total_seconds()

# check if there is any failure 
temp_5k_in_seconds.isna().sum()
# Out:
# 229

# %% [markdown]
# We can see there are some conversion failures and we want to know why. Below locates the NaNs and checks the original values. We want to make sure that we do not lose any info.

# %%
print(df['5K'][np.where(pd.isna(temp_5k_in_seconds))[0]])

# Another way to debug: 
# for i, str in enumerate(df['5K'].to_list()):
#     try:
#         pd.to_timedelta(str)
#     except:
#         print(i)
#         print(str)
#         break
# Out:
# 2327     -
# 3384     -
# 3860     -
# 7747     -
# 8897     -
#         ..
# 76395    -
# 76478    -
# 77631    -
# 78322    -
# 79349    -
# Name: 5K, Length: 229, dtype: object

# %% [markdown]
# Now we convert all time related columns:

# %%
columns = ['5K', '10K', '15K', '20K', 'Half', '25K', '30K', '35K', '40K', 'Pace', 'Proj Time', 'Official Time']

for column in columns:
    df[column] = pd.to_timedelta(df[column], errors='coerce').dt.total_seconds()

# %%
df.dtypes
# Out:
# Unnamed: 0       float64
# Bib               object
# Name              object
# Age                int64
# M/F               object
# City              object
# State             object
# Country           object
# Citizen           object
# Unnamed: 9        object
# 5K               float64
# 10K              float64
# 15K              float64
# 20K              float64
# Half             float64
# 25K              float64
# 30K              float64
# 35K              float64
# 40K              float64
# Pace             float64
# Proj Time        float64
# Official Time    float64
# Overall            int64
# Gender             int64
# Division           int64
# Year               int64
# Unnamed: 8        object
# dtype: object

# %% [markdown]
# ### Handle Missing Values
#
# Now we are ready to handle missing values. First, we check if each column in this df has missing values.

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0       26630
# Bib                  0
# Name                 0
# Age                  0
# M/F                  0
# City                 1
# State             8993
# Country              0
# Citizen          76198
# Unnamed: 9       79480
# 5K                 229
# 10K                114
# 15K                 51
# 20K                 85
# Half                62
# 25K                 81
# 30K                 88
# 35K                 86
# 40K                 76
# Pace                 0
# Proj Time        53117
# Official Time        0
# Overall              0
# Gender               0
# Division             0
# Year                 0
# Unnamed: 8       79555
# dtype: int64

# %% [markdown]
# Before we do anything to the dataframe, we want to know why there are missing values. It is a good time to check the documentation page and the data source.
#
# From there, we know that State is only filled by USA runners and Citizen is an optional field that most runners chose not to fill when they registered. For the time related columns, missing values may occur becuase a runner's time is not recorded properly at a specific checkpoint.
#
# The columns *Unnamed: 9* and *Unnamed: 8* seems to be human error when the data is scraped. Let's not concern about them right now.

# %% [markdown]
# **Drop the missing values**
#
# If, however, you do not have a reason to figure out why there are missing values (which rarely happens), you can drop rows with NA's:

# %%
temp_na_rows_dropped = df.dropna()
print(temp_na_rows_dropped.isnull().sum())

temp_na_rows_dropped.shape
# Out:
# Unnamed: 0       0.0
# Bib              0.0
# Name             0.0
# Age              0.0
# M/F              0.0
# City             0.0
# State            0.0
# Country          0.0
# Citizen          0.0
# Unnamed: 9       0.0
# 5K               0.0
# 10K              0.0
# 15K              0.0
# 20K              0.0
# Half             0.0
# 25K              0.0
# 30K              0.0
# 35K              0.0
# 40K              0.0
# Pace             0.0
# Proj Time        0.0
# Official Time    0.0
# Overall          0.0
# Gender           0.0
# Division         0.0
# Year             0.0
# Unnamed: 8       0.0
# dtype: float64
# (0, 27)

# %% [markdown]
# It looks like we removed all the data, because each row has at least one missing value. To validate our statement, we can perform the below operation:

# %%
print(df.isnull().any(axis=1).sum())
df.shape
# Out:
# 79638
# (79638, 27)

# %% [markdown]
# The number of rows that has missing values is equal to the number of rows in this dataframe. How about dropping columns with missing values?

# %%
temp_na_columns_dropped = df.dropna(axis=1)
print(temp_na_columns_dropped.isnull().sum())

temp_na_columns_dropped.shape
# Out:
# Bib              0
# Name             0
# Age              0
# M/F              0
# Country          0
# Pace             0
# Official Time    0
# Overall          0
# Gender           0
# Division         0
# Year             0
# dtype: int64
# (79638, 11)

# %% [markdown]
# We dropped all of the "splits" time, which is not ideal for detailed analysis.
#
# **Fill the missing values**
#
# Alternatively, we can also fill na's with appropriate values. In this case, we can fill the missing values with empty strings and 0's, depending on column type.

# %%
temp_filled = df.copy()
for col in temp_filled.columns:
    if df[col].dtype == 'object':
        temp_filled[col].fillna('', inplace=True)
    else:
        temp_filled[col].fillna(0, inplace=True)

temp_filled.head()
# Out:
#    Unnamed: 0 Bib                   Name  Age M/F         City State Country  \
# 0         0.0   3         Desisa, Lelisa   25   M         Ambo           ETH
# 1         1.0   4  Tsegay, Yemane Adhane   30   M  Addis Ababa           ETH
# 2         2.0   8         Chebet, Wilson   29   M     Marakwet           KEN
# 3         3.0  11       Kipyego, Bernard   28   M      Eldoret           KEN
# 4         4.0  10          Korir, Wesley   32   M       Kitale           KEN
#
#   Citizen Unnamed: 9  ...     35K     40K   Pace  Proj Time  Official Time  \
# 0                     ...  6479.0  7359.0  296.0        0.0         7757.0
# 1                     ...  6479.0  7362.0  298.0        0.0         7788.0
# 2                     ...  6479.0  7381.0  299.0        0.0         7822.0
# 3                     ...  6483.0  7427.0  300.0        0.0         7847.0
# 4                     ...  6479.0  7407.0  300.0        0.0         7849.0
#
#    Overall  Gender  Division  Year  Unnamed: 8
# 0        1       1         1  2015
# 1        2       2         2  2015
# 2        3       3         3  2015
# 3        4       4         4  2015
# 4        5       5         5  2015
#
# [5 rows x 27 columns]

# %% [markdown]
# **Impute the missing values**
#
# The split times of some runners are not recorded properly and are set to NaN when we tried to convert time to seconds. In this case, one way to impute these NaN's is to take the portion of official time accordingly.

# %%
columns = [[5, '5K'], [10, '10K'], [15, '15K'], [20, '20K'], [42.195/2, 'Half'], [25, '25K'], [30, '30K'], [35, '35K'], [40, '40K']]

df_imputed = df.copy()

for [miles, column] in columns:
    df_imputed.loc[df[column].isna(), column] = df['Official Time'][df[column].isna()] * (miles / 42.195)

# %%
df_imputed.isnull().sum()
# Out:
# Unnamed: 0       26630
# Bib                  0
# Name                 0
# Age                  0
# M/F                  0
# City                 1
# State             8993
# Country              0
# Citizen          76198
# Unnamed: 9       79480
# 5K                   0
# 10K                  0
# 15K                  0
# 20K                  0
# Half                 0
# 25K                  0
# 30K                  0
# 35K                  0
# 40K                  0
# Pace                 0
# Proj Time        53117
# Official Time        0
# Overall              0
# Gender               0
# Division             0
# Year                 0
# Unnamed: 8       79555
# dtype: int64

# %% [markdown]
# Note that any method dealing with missing values adds additional bias to our data. Choose them wisely!

# %% [markdown]
# ## Explanatory Data Analysis (EDA)
#
# ### What are the differences?
#
# Data wrangling and exploratory data analysis (EDA) are two important steps in the data analysis process. While they are related, they serve distinct purposes.
#
# **Data wrangling** focuses on cleaning, transforming, and preparing raw data for analysis. It ensures data quality and prepares it for further processing. Techniques include cleaning, preprocessing, and aggregation.
#
# **Exploratory Data Analysis (EDA)** involves analyzing and visualizing data to gain insights, identify patterns, and understand its structure. It explores relationships between variables, detects outliers, and generates hypotheses.
#
# Data wrangling sets the foundation for EDA by ensuring data quality and structure, while EDA helps in understanding the data and generating hypotheses for further analysis. Both steps are crucial in the data analysis process and often go hand in hand.

# %% [markdown]
# ### Data Exploration
# First, we deplay summary statistics for numeric columns.

# %%
print("Summary statistics:\n", df.describe())
# Out:
# Summary statistics:
#           Unnamed: 0           Age            5K           10K           15K  \
# count  53008.000000  79638.000000  79409.000000  79524.000000  79587.000000
# mean   13251.666692     42.415166   1527.392361   3056.006124   4610.047307
# std     7651.406646     11.355453    238.229185    479.974721    736.051219
# min        0.000000     18.000000    883.000000   1783.000000   2697.000000
# 25%     6625.750000     34.000000   1355.000000   2711.000000   4085.000000
# 50%    13251.500000     42.000000   1497.000000   2992.000000   4508.000000
# 75%    19877.250000     50.000000   1654.000000   3312.000000   4997.000000
# max    26597.000000     84.000000   3350.000000   6436.000000   9705.000000
#
#                 20K         Half           25K           30K           35K  \
# count  79553.000000  79576.00000  79557.000000  79550.000000  79552.000000
# mean    6213.512727   6559.22601   7857.497744   9595.217197  11409.743715
# std     1019.400499   1077.86020   1328.821194   1670.760154   2024.275266
# min     3628.000000   3841.00000   4565.000000   5519.000000   6479.000000
# 25%     5495.000000   5801.00000   6928.000000   8432.000000   9998.000000
# 50%     6064.000000   6399.00000   7648.000000   9326.000000  11079.000000
# 75%     6734.000000   7108.00000   8527.000000  10446.000000  12463.000000
# max    16180.000000  17237.00000  16566.000000  27398.000000  24691.000000
#
#                 40K          Pace     Proj Time  Official Time       Overall  \
# count  79562.000000  79638.000000  26521.000000   79638.000000  79638.000000
# mean   13211.480380    534.086529  14110.096904   13989.929167  13273.683417
# std     2357.102722     95.090340   2466.363480    2492.272069   7663.512720
# min     7359.000000    296.000000   7965.000000    7757.000000      1.000000
# 25%    11571.000000    468.000000  12394.000000   12258.000000   6637.250000
# 50%    12830.000000    519.000000  13692.000000   13592.000000  13273.500000
# 75%    14469.000000    585.000000  15411.000000   15325.000000  19910.000000
# max    28752.000000   1470.000000  38536.000000   37823.000000  26629.000000
#
#              Gender      Division          Year
# count  79638.000000  79638.000000  79638.000000
# mean    6693.365064   1618.782792   2015.997639
# std     3927.594786   1448.369424      0.815852
# min        1.000000      1.000000   2015.000000
# 25%     3319.000000    510.000000   2015.000000
# 50%     6637.000000   1179.500000   2016.000000
# 75%     9955.000000   2219.000000   2017.000000
# max    14581.000000   6004.000000   2017.000000

# %% [markdown]
# Some example questions to ask:
#
# - How many runners participated 3 years in a row? What are their names? (For simplicity, we do not consider people with the same names)

# %%
# Create separate sets of names for each year
names_2015 = set(df[df['Year'] == 2015]['Name'])
names_2016 = set(df[df['Year'] == 2016]['Name'])
names_2017 = set(df[df['Year'] == 2017]['Name'])

# Find the intersection of the three sets
common_names = names_2015.intersection(names_2016, names_2017)

# Length of common_names
common_names_length = len(common_names)

# Print the length
print("Number of runners who participated 3 years in a row:", common_names_length)

# Print the common names
for name in common_names:
    print(name)
# Out:
# Number of runners who participated 3 years in a row: 2318
# Ultsch, Janette
# Verderame, Jyoti
# Cheng, Francis
# Cronin, Brian S.
# Bowman, Stacey
# Yu, Alex
# Clayton, Jennifer K
# Weibeler, Mickey
# Krzynowek, Lauren K.
# Bellerive, Robert
# Hoffman, Bill
# Jacobs, Rubesh
# Rich, George F
# Pilotte, Micho
# Schreiber, Maria E.
# Tocha, Wendy
# Lewullis, Kimberly J
# Levy, Wayne A.
# Brazeau, Gerald
# Mrowka, Marcin
# Di Iulio, Tara F
# Drzewiecki, Alexis
# She, Chunfeng
# Couture, Nathaniel
# Alzate, Alejandro
# Gronquist, James M
# Solomon, Jennifer J.
# Dedeo, Carrie-Anne
# Mundhenke, Gary L
# Johnson, Derek M
# Jones, Jessica L
# Hetherington, Alexander G
# Quandt, Julie M
# Nanfelt, Scott B.
# Garcia, Tony T
# Jensen, Jan
# Gill, Catherine W
# Crumpler, Katrina
# Hetzer, Nicole K
# Benson, Cory R
# Meixelsperger, David
# Mandak, Greg
# Minella, Paula J.
# Lipcon, Meghan
# Sheridan, Jennifer F.
# Stoops, Jody
# Moore, Jared
# Cashen, Dennis
# Panzek, Steven
# Lederer, Peter
# Kaye, Celeste A.
# Stanley, Michael John
# Kuzma, Cindy
# Cass, Laurie
# Dumont, Bill
# Byers, Christine
# Forestell, Elizabeth
# Cater-Cyker, Zach
# Chun, Yoon
# Bertolami, Leo
# Ater, Neal
# Caldwell, Vincent
# Tupper, Debbie M.
# Grupp, Matthias
# Siciliano, Seth H
# Kirleis, Thor
# Maher, Allison
# Rochman, Paula
# Stanton, Roger C.
# Eisenberg-Argo, Susie
# Chung, Jay
# Takaoka, Masahiro
# Koy, Saath
# Miller, Kenny
# Coulter, William
# Brown, John T
# Claycomb, Mark C
# Loughnane, Kevin
# Hovanic, Phillip M
# Gealy, Robert
# Howie, Alan D
# Crockett, Paul
# Barbee, Kristie
# Melander, Matthew P
# Sullivan, Mark A.
# Groner, Roberta
# Roberts, Ann M
# Vonarx, David L
# Garvey, Eileen M.
# Coogan, Rachel
# Damiano, Jeffrey
# Bucala, Richard
# Slyer, John T
# Velmer, Zhihong
# Tremblay, Christian
# Craig, Jack
# Triest-Hallahan, Pam
# Fogg, Karen
# Steele, Graeme S.
# Takeshita, Kazunobu
# Watson, Jeffrey R
# Sauriol, Denise
# Cauller, Greg
# Carrijo, Ivaltemir B. Sr.
# Fairley, David
# Laitman, Robert
# Gurtov, Jamie
# Ziol, Jeffrey J.
# Cabral, Manuel
# Ney, William B
# Morris, James
# Romanelli, Frank
# Scaletta, A J.
# Cooper, Steve
# Herra Arroyo, Gabriela
# Barton, Richard
# Wolski, Greg
# Miller, David
# Ito, Masahiko
# Danbe, Janna
# Feliciano, Rose V
# Warncke, Rich
# Dunn, Marie E
# O'Donoghue, Mary E
# Autrey, Jonathan
# Barton, Crystal
# Nieves, Lizbeth
# Barnett, David P
# Sanford, Kip
# Miller, Joyce
# Mertz, Christopher
# Montgomery, Christopher
# Osada, Noriko
# Trampe, Travis
# Sargent, Pamela
# Hayes, Dave
# Neylon, Dermot
# Hamilton, Gregory W.
# Aguila, Anton
# Maliszewski, Steve
# Solomine, Kim
# Rivers, Kylie
# Afsar, Arma
# Fay, Jennifer M
# Anderson, Amy
# Thacker, Ben
# Vardi, Moshe
# Surprenant, Albin
# Jaruszawicus, Julee M.
# Yabu, Yoshie
# Norton, David
# Cusson, Michel
# Ho, Keng Hong
# Pugsley, Stephen M.
# Hiorns, Bruce F.
# Simons, Michael E
# Dale, Laurelly
# Zhou, Fan
# Garcia, Gilberto
# Proulx, Alexandre
# Sparks, Jenny
# Tsoucas, Daphne
# Brown, Tracie
# Ross, Ken N
# Morrish, Karen
# Degrace, Claude
# Deady, Jeffrey R.
# Rylyakov, Alexander
# Foil, Jennifer
# Ushida, Matsunori
# Perun, Diane
# Abbott, Wendy
# Woodward, Jeremy L.
# Arendtsen, Deb
# Orten, Mercedes E
# Greer, Catherine
# Segal, Kayla
# Corona Iturriaga, Roberto
# Harley, Stephen
# Schaal, Dan
# Sullivan, David E.
# McGinley, John
# Shilling, Kevin
# Arnst, Timothy F.
# Kammerer, Richard E
# Bachand, Sarah L
# Moyao, Irma
# Pulliam, Joseph
# Gonzales, Gregory G.
# Fleury, Simon
# Kiviaho, Colin
# Kadala, Kristyn
# Ramirez, Jorge A.
# Mitchell, Thomas J.
# Estrada, Gina L
# Amster, Michael B.
# Pond, Kyle K
# Palombaro, Matthew F
# Weisberg, Scott R.
# Wood, Julie
# Rondeau, Stephen
# McNeil, Mike W.
# Washburne, Mark
# Howland, Jennifer
# Cline, Lisa A.
# Cantini, Adam
# Lehew, Bob
# Jones, Paul W.
# Knight Pech, Heather
# Devine, David C
# Catinazzo, Bob
# Combopiano, Frank
# Chovin, Colin
# Harding, Gene
# Ashcom, Susan R
# Moulton, Anthony R.
# Koenig, David
# Park, Holly
# Burfoot, Mairi
# Henning, Sonja
# Tylova, Veronika
# Delaney, Nancy
# Hendrickson, Cherie
# Goff, Kim Marie
# Clash, Daniel C
# Fantasia, Frank R.
# Gao, Yun
# St-Jacques, Carl
# Stevenson, David
# Brozowski, Derek T.
# Christensen, Kaidree M
# Chankseliani, Larissa
# Schlereth, Joe
# Black, Darren M
# Mihalcin, Jennifer
# Davis, Charlotte
# Pattee, Corey S
# Kleckner, Dave
# Williams, Bj
# Conklin, Marion
# Steeves, Kelley E.
# Kawano, Koji
# Hayes, Ronald
# Hartstein, Taylor F
# Kent, Cherry C
# Kerper, Warren
# Perry, Antonia
# Golden, Alicia
# Ayr, Jason M.
# Fucinaro, Dan
# McCaffrey, Ryan F.
# Taylor, George
# You, Nithi
# Cilli, Mark
# Staton, Jamie
# Trotter, Jill M
# Gomez Gamboa, Natalia
# Pham, Chinh H.
# Moore, Omar L
# McMahon, Patrick M.
# Lohnes, Steve
# Glass, Dianna
# Imbergamo, Matthew G.
# Kukel, Scott
# Cockerham, Ross
# Grieves, Michele
# Barrionuevo, Natalia
# Smith, Kevin
# Randolph, Ryan
# Brillinger, Matt
# Peffall, Christopher
# Blankenship, Edward
# Malone, Emily
# Larose, Jean
# Guertin, Douglas P.
# Stianchi, Robert J
# Guzinski, Carol
# Ruttens, Koen
# Flemming, Todd
# Campanelli, Vince
# Winchester, Susann
# Houston, Richard F
# Viviano, Susan L
# Wilderman-Hay, Mary-Ellen
# Marshall, Rob
# Egan, Alexander
# Cottrell, Bill
# Gilman, Matthew S.
# Kanamura, Shizuo
# Wheeler, Patrick
# Young, Carl R.
# Arriola, Francisco Jr.
# Castillo, Ronald
# Therriault, Megan A.
# Ho, Tom
# Hickle, Jay
# Stevens, Aaron Z.
# Hacker, Kevin
# Kono, Michimasa
# Wasko, Myrlin
# Maguire, Daniel J.
# Pawlowski, Eric P.
# Klisch, Joerg
# Ivy, Lea
# Sexton, Carol
# Moore, Jim
# Nelson, Charlie
# Roybal, Robyn
# Vincent, Anthony
# Korfhage, Mike A
# Mitropoulos, Arielle M.
# Wolfberg, Rachel A.
# Gerow, Warren H III
# Mattingly, Ashley R
# Beauchesne, Eric
# Dierig, Lori
# Pennymon, Charlene
# Diamond, Anthony
# Emoff, Ray
# Childs, Dennis A.
# Brady, Raymond F.
# Vigue, Ronald
# Darrenkamp, Bonnie
# Lyons, Bryan P.
# Kearney, Lauren
# Valco, George J
# Normandin, Jocelyn
# Reisz, Monica
# Girard, Christine
# Tattersall, Theresa M
# Lessard, Andre N
# Huberty, Bryan
# Wimberly, Jay J
# Silva Toro, Oscar A. Sr.
# Turchenko, Vlad
# Kurdziel, Lisa M.
# Robey, Thomas
# Weaver, David E.
# D'Amanda, Kevin
# Young, John D.
# Brill, Zachary N.
# Spence, Lynne
# Olson, Tim
# West, Spencer D
# Bourdon, Melissa
# Perez-Verzini, Marcelo
# Yunker, Tom
# Otsuka, Takuo
# Welton, Craig S.
# Hasegawa, Naomi
# Lund, Mario J.
# Hower, Sharon K
# Capicio, Chris A
# Koch, Shelley A
# Rosenblum, Michael
# Pellerin, Annie
# Young, Jeffrey
# Blom, Sam
# Bonasso, Laurie R
# Colina, Noel
# Adams, Julia A.
# Montgomery, Darlene
# Hopper, Barrett
# Burger, Garrett
# Doyon, Gregory
# Coffee, Kyle
# Clark, Roger B
# O'Flaherty, Anthony
# Carroll, Brian K.
# Gutierrez, Alejandro
# Cunningham, Thomas T
# Waisbren, Susan E.
# Felty, James A.
# Mburu, Wes
# Trussas, Peter J
# Breen, Edward
# McCarron, Paul
# Allen, Michael G.
# Kennedy, Pamela
# Dudaryk, Kathleen M
# Shigezumi, Teiko
# Menendez, Jessica
# Larkin, Stanley
# Susi, Rebecca M.
# Paris, Michel
# Chase, Thomas M
# Scott, Bobby
# Howick, John
# Morris, Jonathan R
# Kajino, Meg
# Rauch, James
# Barry, Timothy F.
# Holmboe, Dag
# Harris, Sarah E
# Drummond, Tom
# Weeks, Lauren
# Conti, Christine M.
# Loughran, Lisa
# Brown, Gregory E
# Horwitz, Alan
# Ferreri, Anthony
# Schulte, Shiloh A
# Lopez, Elmer
# Penson-Boucher, Joanne
# Randolph, Bret
# Vandeventer, Alix
# Ephraim, Eliot
# Wesemann, Duane
# Carrens, Cleve
# Carpo, Amanda
# Schmidt, Eugene
# Wang, Yi
# Palmer, Nadine
# Steeves, Madelyn
# Syvertsen, Kai
# Trueman, Rick
# O'Rourke, Martha
# Engtrakul, Chaiwat
# Ziegler, Juergen
# Rogers, Maureen H.
# Zbikowski, Alissa
# Oliva, Kristin
# Kluge, Graig E
# Marsh, Adam R.
# Mui, Dennis
# Burke, Patrick J
# Nettik, Jenni
# Slack, Carina
# Anthony, Larry
# Ollerman, Esti
# O'Brien, Jamie
# Brossoit, Pierre
# Gordon, Stephanie
# Mikhael, Nicole
# Dussault, Robert
# Broughel, Nancy
# Grinage, Janine
# Fernandez De Bobadilla, Pablo
# Champagne, Kathleen A
# Flesher, Jim
# Ito, Atsushi
# Hoff, Wendy M
# Smith, Joanne
# Childs, David F.
# Burrows, Jennifer
# Gazza, Jennifer E.
# Hammond, Natalie
# Rothschild, Daniel
# Craddock, Michele
# Valladares, Maureen
# Watanabe, Yoko
# Breault, Ted
# Carroll, Joseph P.
# Bauman, Mark E.
# Decourcy, Tracy
# Rago, Constantino
# Boyer, Linda
# Akers, Chip
# Fogarty, Karen
# Spina, Jennifer
# Rech, Dan
# Huff, Kris
# Spaulding, Tracy
# Zoback, Scott
# Bihl, Scott A.
# Crader, William
# Sweeney, James A.
# Busa, Ashley
# Pilotti, Renee
# Lu, Phil
# Langarica, Claudia
# Chamberlin, Rachael
# Park, Deric M
# Soares, Greta
# Woskow, Greg
# Jones, Kerry M
# Pontrelli, Mike
# Jimenez, Freddy
# Labranche, Sebastien
# Regan, John
# Isfan, Warren
# Morrison, Paul D.
# Randolph, Paul R
# Sutherland, Judith A
# Wun, Michelle
# Goineau, Veronique
# Mosaddeghi, Mahmood
# Hauck, Penelope V.
# Sigman, Marla F.
# Collins, Brian
# Tsujishita, Masao
# Walls, Cindy
# Zhang, Yu
# Chen, Sapphire
# Murphy, Sean P.
# Mason, Rick
# Landers, Harry
# Moscariello, Joseph
# Levey, John
# Welch, Brian
# Berger, John P
# Solarz, Christopher C
# Horan, Kelly P.
# Villafane, Juan
# Gerhardt, Wayne J.
# Duguay, Sylvain
# Carlucci, Lisa
# Hammers, Bill
# Brown, Kate
# Marino, Carl
# Ruland, Deanna
# Raffetto, Louis
# Ezekiel, Ephraim
# McMenemy, Jerry E.
# Lambert, Stan
# Caraang, German
# Keane, Deirdre M
# Johnson, Tom M
# Kendall, Esther
# Prigge, David
# Hotton, Josee
# Chiavetta, Judi
# Murphy, Cindy J
# Karmacharya, Santosh
# Bender, Laura
# Saucier, Bert
# Glynn, Scott
# Anderson, Matt
# Zheng, Jie
# Arias, Eduardo
# Zicko, Tatyana K
# Hage, John L.
# Knoll, Nancy
# Howard, Doug
# Oketani, Shigenari
# Yavonditte, Joe
# Jonca, Aleksander J.
# Walden, Lawrence M.
# Stackpole, Peter
# Habte, Habtom
# Adams, Pamela S
# Devries, John
# Kim, Daniel K.
# Choi, Stephanie
# Wheeler, Robert A.
# Dillon, Michelle A
# Yamada, Ichio
# Wagner, Erica
# Klein, Anne E
# Kovalchick, Christopher
# Perry, Tim
# Scholl, James E.
# Ebener, Kenneth W
# Pultorak, Jim
# Nechleba, Debi
# Treitler, Christian
# Smith, Brian S
# Tonnu, Xuanhuong
# Kramer, Jason
# Chekijian, Sarkis
# Steele-Belkin, Dara
# Jean, Michael
# Urbanski, Bill
# Coffman, Steven D.
# Molloy, Amy
# Yesian, Bonnie
# Fagan, Brian
# Bucci, Gaetan
# Bryant, Jennifer
# Bradley, Elizabeth M.
# Chase, Eric
# Keshian, Gregory
# Morrison, Michael S
# Senkowski, Jeff P
# Isenberg, James A.
# Warburg, Shannon
# Della Serra, Rocco
# Romito, William
# Kalinyak, Joseph
# Sutherland, Lisa H
# Berman, Art
# Bryan, Joel
# Kovacs, Attila
# Novas, Jacqueline
# Aitken, Miles
# Takeguchi, Kathy
# Johns, Richard A.
# Reilly, Meg
# Robbins, Dennis G
# McCarthy, Kevin B.
# Mourad, Derek J.
# Krasniewicz, John
# Rosendahl, Bruce
# Connolly, Beth D.
# Schafer, Robert J
# Sugrue, Nicolle
# Pender, Seamus
# Rotundo, Cesare
# Nurse, Elizabeth R
# Adipietro, Frank
# Hozik, James
# Sharp, Joshua A.
# Makishima, Ryuhei
# Pepin, Megan
# Sweeney, Rob
# Kimberley, Glenn
# Juenger, Todd
# Desforge, Peter
# Radtke, Andrew C
# Manikas, Vasilli
# Doherty, Meaghan
# Quesada, Jason
# Deer, Timothy R
# Knupp, Sherri L.
# Ueda, Akifumi
# Ma, Calvin
# Ryan, Patrick J.
# Becker, Russell H.
# L'Abbe, Fabienne
# Jonardi, Richard
# Dodge, Robyn L
# Kerr, Abbe
# White, Alex
# Suit, Dickson
# Manewell, Adam
# Cardona-Suarez, Ruth
# Makowski, Joan L
# Tisch, Robert
# Takahashi, Rie
# Berry, Sara
# Berneburg, Justin G.
# Li, Lucy G
# Daye, Ryan
# Pete, David T.
# Crandall, Jeremy P.
# Pschorr, Jamie F
# Steele, Jay
# Kraus, Lisa A
# Shaw, Shirley Y
# Bradley, Pat
# Pangapalan, Fred
# Thomas, Kurt
# Serna, Dennis
# Gutjahr, Joey
# Wege, Mike
# Mahoney, Steve A
# Slade, Steve
# Thompson, Lisa
# Ryan, Jim
# Fuller, Jan H.
# Reynolds, Renee M
# Labreche, Hafsa
# Wright, Brian
# Martin, Terence J.
# Tuluie, Tania
# Moran, Troy J.
# Fritzsche, Jennifer L
# Clarke, Travis
# Bukowski, Nichole
# Gorski, Russ
# Murphy, Terry
# Lenden, Lise
# Vangampleare, Stephen
# Wert, Jonathan M
# Wolfe, Michael
# Dunn, Peter
# Fitzgerald, Carrie C.
# Lundine, Sarah
# Roach, Ami
# Soler, Darin
# Blois, Michael
# Tam, Megan E
# Rizo Pinzon, Miryam S. Jr.
# Cronin, Christine
# Zastera, Martin
# Welch, Brian C
# Rayl, Brian K
# Masiello, Frank J. Jr.
# Tobin, Jenni K
# Won, Richard
# Powers, Ashley N.
# Hooper-Stanley, Kim
# Harper, Matt
# Crane, Brian
# Smithson, Peter
# Oates, Brian G.
# De Bortoli, Bruno
# Hatcher, Denise
# Kasten, Brian
# Madeo, Bill
# Vida, Joseph
# Schoenberg, Jon S.
# Youth, Tom
# Patel, Raj
# Venkat, Subbu
# Caredio, Elisa
# Scoville, Morgan B.
# Bergin, Heather
# Marmoreo, Jean E.
# Doherty, Patrick
# Clapp, Tim H.
# Huprich, Don
# Rowland, Dean
# Lecuyer, Lindsey B.
# Kean, Mairead K.
# Odlaug, Andrew P
# Sacchini, Alberto
# Hauff, Chadwick
# Martin, Sarah
# Huckle, Nathan E
# Byers, Ray
# Leon, Oscar
# Crawford, David D.
# Nishimura, Akira
# Brown, Gerald
# Karakoyunlu, Deniz
# Dragsbaek, Ann-Michele
# Andrae, Dana J
# Grossi, Anthony L.
# Murphy, Michael E.
# Joseph, Paul D.
# Garfield, David
# Hudyma, Wade W
# Wong, Robert
# Ferry, J. Alain
# Gustafsson, Kristin D
# Kosugi, Junko
# Sabio, Hernan
# Walters, Steve
# Courtney, S. Mark
# Tam, Benny
# Dunfey, Bob
# Bowe, Wendy
# Haas, Rick
# Litka, Megan
# Dixon, Karen L
# Andersen, Lee K
# Slepchenko, Alexander
# Smart, Larry
# Ozbolt, Joe
# Schoeneck, Julie A
# Pearce, Cathy
# Cherington, Sarah
# Beiers, John
# Brown, Geof
# Asgeirsson, Amanda K
# Buxton, Wanda
# Randolph, Ross G.
# Larson, Daniel C.
# Hinkle, Dustin
# Rodriguez, Luz M.
# Byerly, Kevin
# Vega, Alvaro
# Elmrabet, Karim
# Koning, Katie
# Caputi, Gaetano
# Doherty, Michael P.
# Toomey, John F.
# Condon, Kieran
# Kunkel, Sven
# King, Tony
# Dakai, Carol M
# Lindgren, David M.
# Morton, Barry
# Harron, Jim
# Burkard, Anita
# Wan, Yongbing
# Travers, Robin L.
# Harrod, Rene
# Russ, Garry
# Hanson, Keith P.
# Egler, Brian D.
# Oser, Tim
# Brinkruff, Claudia
# Robitaille, Gerald
# Hamilton, Joe M.
# Yang, Lulu
# Vincent, Amelia
# Rossi, Michael
# Clary, Rick
# Weimar, Christopher
# Cote, Robert H. Sr.
# Oliver, Malcolm
# Troland, Dan
# Naruse, Yoshitaka
# Cook, David C.
# Heath, Michael B.
# Hammervold, Jerry
# Green, Ha
# Blevins, Christina
# Tecce, Michael
# Caron, Jeanne
# Wisseman, Bud
# Farkash, Lauren
# Mousaw, Tara
# Brophy, Patrick I.
# Hershey, Steven R.
# Young, Cheryl
# Burkholder, Bryn
# Feder, Cheryl
# Larose, Frederic
# Schroeder, Marylee
# Callahan, Robby
# Merino, Keila L
# Cruz, Aristides I. Jr.
# Canzius, Patrick
# Minervino, John R
# Perantoni, John
# Chase, Sharon A.
# Chewning-Kulick, Travis G.
# Trachy, Jacques
# Battin, Beth
# Orloff, Conrad F
# McCourt, Caitlin
# Kato, Satomi
# Spraker, Rosemary
# Knoble, Jeanna L
# Sullivan, Tim
# Marty, Michael
# Sakamoto, Takashi
# Fuentes, O
# Dolney, Daniel
# Tanner, Pamela
# Faria, Fil
# McCormick, Michael A.
# Bower, Michael J.
# Rook, Geoff
# Connolly, Paull
# Williams, Angie M.
# Germain, Daniel
# Kaczka, Greg
# Bradley, Larry
# Monheim, Christopher
# Fogarty, Sean J.
# Law, Kim
# Foley, Paul S.
# Nixon, Sarah
# Waterman, Mike
# Hermon, Maria
# Battoo, Christopher
# Names, Curtis
# Plamondon, Lise
# Morris, Thomas M
# Helgerson, Jay F.
# Welch, Michael
# Salter, Lori L
# Boulay, Pierre
# Hiatt, Jon M
# Beard, Harold
# Yitref, Gedion
# Richard, Christopher J
# Garneau, Simon
# Desrosiers, Helene
# Tobias, Tara
# Albinsson, Stefan
# Eversman, Michelle
# Shea, Mary Kate
# Grisham, C Keith
# Landry, Stephen C
# Rigsby, Scott
# Quinn, Holli S
# Hehn, Cara L.
# Sornberger, Julie
# Mamzic, Curtis E
# Slack, Ron
# Delieutraz, Ana F
# Cidlevich, Stephen M.
# Sims, Jay
# Takahashi, Toru
# Wolcott, James B. II
# Bonilla, Veronica
# Miskell, Clif
# Daley, Leo H. Jr.
# Sved, Bill
# Liguori, Michele
# Stange, Michael
# Rittenberg, Brian N
# Johnston, David F.
# Grimm, Brian G
# Cervantes, Claudia
# Britt, Faye
# Halstead, Amy M
# Malloy, Kevin
# Medina, Benjamin
# Miganowicz, Jonathan I
# Mauger, David
# Spoor, Karen M
# Rose, Andrew P
# Leslie, Gretchen A
# Capone, Dean
# Masson, Gilles
# Doud, Laura L
# Clapp, Christopher C.
# Otero, Julie
# Galay, Melanie K
# Chaoui, Carol
# Wirth-Cauchon, Alex
# Kheyfets, Julie
# Flynn, Joseph T.
# Cutler, Amy C.
# Li, Guannan
# Brancato, Melissa
# Boland, Thomas
# Gardner, Preston
# Cantu, Hiran
# Raftery, Brendan P.
# North, Simon
# Foster, Gregory T
# Varner, Carrie G
# O'Higgins, Brian
# Hall, Alden W
# Kounlasa, Sinthy
# Perry, Natalie R
# Cunningham, Corrine E.
# Bernstein, Shelley
# Cormie, David
# Lennox, Scott
# Wang, Hanju
# Aziz, Meredith
# Ptacek, Lubor
# Harder, Tim
# Scoffin, Peter
# Widnall, William S.
# Gatz, Elizabeth
# Jennings, Thomas
# Campbell, Stewart
# O'Sullivan, Amy
# Conklin, Sean P
# Neary, Noreen
# Wong, Adrian
# Gross, Benjamin
# Mori-Stoodley, Josephine
# Gaitten, Joseph S
# Smith, Daniel J
# Thompson, Steve
# Poole, Vernessa
# Wilson, James M.
# Brady, Lance
# Zeman, Nicolle
# Wilson, Jill A.
# Larcom, Maryellyn
# Hollenberg, James P
# Miller, Stephanie
# Weiler, Meghan
# London, Wendy B.
# Neufeld, Jill
# Stanley Torres, Dana
# McPherson, Martina
# Welch, Susan
# Carreiro, Patricia
# Taormina, Nick
# Menovich, Michael J.
# Oguz, Baki
# Lepp, Harry
# Kolda, Lisa
# Conley, Steve
# Zaremba, Monica A
# Robidoux, Kyle R.
# Mesbah, Tayeb
# Zappala, Dante
# Hibbitts, Marla
# Clements, Bill
# Quinn, Thomas P.
# Carboni, Jeffrey D.
# Rosario Cookson, Debra
# Dewar, Walter S
# Waldecker, Jaime
# Mullins, Padraig
# Kong, Ric
# Gingras, Amy J
# Alcock, Bernard L.
# Guitard, Brenda
# Bernardi, Shawn
# Eichert, Jon
# Burfoot, Amby
# Crandall, Robert
# Pham, Phuc C
# Smith, Lester H.
# Fischer, Timothy
# Massefski, Walter
# Broderick, Brittany
# Gower, Devra
# Valencia, Dolores
# Szakal, Steve
# Bruce, Susan
# Huang, He
# Jin, Michele
# Schwarz, Donald J.
# Kwong, Angela
# Jacobson, Doug
# Kreider, Kimberly S
# Sullivan, James
# Graham, Scott R.
# Lacava, Rebekah
# Shoemaker, Mae
# Tabbal, Luai
# Wilson, Pete
# Beaulne, Rebecca M.
# Bentley, Bettina B
# Palandri, Shawn
# Acker, Del
# Bui, Jason
# Solberg, Bryon
# Kim, Soohan
# Chorney, Yuki
# Walsh, Sean J
# Labowsky, Sarah T.
# Connolly, Katherine
# Girard, Mathieu
# Volonsevich, Katia
# Morinville, Anne
# Tiozzo, Angelo
# Husak, Tyler
# Ackerman, Alissa
# Nelson, Michael P
# Novotny, Amy
# Deeg, Thomas J
# Rogers, Tracie J
# Couture, Philippe
# Hughes, Grant
# Davis, Michael
# South, Jodi A
# Ross, Scott
# Brickley, Patrick
# Barrie, Erin
# Colin, Alberto
# Schubert, Sarah
# Yigzaw, Yinges
# Chambless, Amy
# Trang, Danh
# Baida, Andy
# Schulz, Heather
# Baumgart, David
# Maher, Jeffrey G.
# Breault, Kelly
# Garcia-Dunna, Eduardo
# Labare, Megan
# Wong, Ping Yee
# Hudak, Lauren
# Ordman, Beth
# Trombatore, Ken
# Sellars, Cassie
# Hanna, Howard
# Chang, Kelly
# Christie, Robert
# Bach, Donghoon
# Lavergne, Line
# Hurst, Nicole
# Burgoon, Audrey
# Galer, Stacy
# Furrer, Amanda
# Jung, Joann H.
# Mehler, Laurel J
# Saxton, Ron
# Pelletier, Mark W.
# Lohner, Kevin
# Innis, Amy M.
# Dunn, Christopher M.
# Sinisi, Rocco
# Fraser, Jamie
# Truxillo, Adrienne
# Akeson, Wendy C.
# O'Donohue, Kelli M.
# Hancock, Chris
# Hritzo, Greg
# Moyer, Dave
# Scivally, Steve
# Jamison, Joshua
# Maxey, John
# Durbin, Bill
# Day, Michelle M.
# Trumper, Peter S.
# Wegener, Joel D
# Jakubowitch, Andrew
# Cryer, Steve
# Dagdigian, Kelly C.
# Wu, Liang
# Cameron, Kerry
# Reny, Audrey E.
# Winslow, Kathleen L
# Quinteros, Martin
# Perez, Miguel A. Sr.
# Dehnashi, Zarah
# Childs, Raymond
# Townsend, Deborah M.
# Hampton, Joy
# Bosse, John P.
# Sullivan, John T.
# Donovan, Caren A.
# Trulla, Riccardo
# Sloan, Bradley
# McDonough, Kaitlyn L.
# Spanos, Marissa
# Hillyard, Matthew
# Boyce, Gary
# Hughes, Gregory
# Holbik, Edward J.
# Enright, Ryan
# Montefusco, Sue
# Donahue, Joseph P
# Grossman, Lawrence C
# Cohen, Howard S
# Hernandez, Kathy
# Kaiser, Michael
# Alderton, Richard
# Rosales, Isela
# Prince, Akiko
# Lund, David
# Wind, Jay Jacob
# O'Meara, Marc C.
# Jones, Anne
# Li, Xinli
# Treece, Hope
# Aikin, John L
# Peck, Ronald F.
# Dawes, Jaime
# Benestad, Brian
# Fiske, Darrell
# Henry, Todd J
# Tokgoz, Sadik
# Dubois, Craig W
# Lanoie, Yann
# Bennett, Darren J.
# Vanberg, Georg
# Brown, Dale
# Sawicki, Jeffrey
# Painter, Ted
# Hair, Kathleen
# Keener, Barlow
# Splete, Heidi
# Tong, Frank
# Bence, Bonnie C.
# Howell, Jason A
# Pierce, Clayton J.
# Fuerte, Jesus
# Gingras, Donald
# Cook, Brian
# Ponce De Leon, Maricruz
# Ronayne, Michael C.
# Comment, Kristen
# Hirshberg, Philip M.
# Krieche, Issam
# Bigoni, Brian
# Bartlett, Lori A.
# Bolha, Jonathan
# Schubert-Akin, Jennifer
# O'Hanlon, Michael
# Gonzalez, Eloy
# Beach, Timothy
# Hall, Dan
# Kelly, Katy
# Cole, Jim
# Sullivan, Steve P
# Campbell, Delgado
# Hyland, Sean P.
# Boudalia, Said Sr.
# Gaizauskas, Ivar
# Foley, Patrick J.
# Ragan, Ty
# Hung, Patty A.
# Langley, R J
# Dominguez, Maria
# Beiers, Katherine
# Milton, Kimberly
# Walth, Natasha
# Mitchell, Traci
# Cass, Mary
# Cortez, Andrew
# Cummins, Brian
# Lablans, Mirjam
# Locandro, Will
# Lavoie, Marc
# Fletcher, Sarah
# Kmiec, Ronald
# Doubiany, Othman
# Tomlinson, Betsy
# Fortier, Helene
# Asher, Bobby
# Yudelman, Errol
# Freni, Michael J.
# Burke, Jason
# Rawat, Jitendra
# Zaferos, Audrey
# Nowell, Krissy
# Chhun-Dugger, Sokha
# Velde, Ty
# Neland, Kristin
# Clem, William M
# Benoit, Alexandre
# Thompson, John L.
# Yamada, Miki
# Lindquist, Lisa M.
# Gadrow, John J.
# Tegano, John
# Tremblay, Guy
# Gaasch, Wade
# Whalen, Michael
# Takakusaki, Yuko
# Clark, William
# Oba, Yukiko
# Wilson, Grant
# Finelli, Lauren
# Fannon, Alicia
# Else, Mike
# Sunami, Motoshi
# Charles, David
# Rossettini, Katie
# Breeding, Evan M.
# Griffin, Thomas M.
# Brown, John J.
# Ornelas, Zachary
# Hage, Robijn
# Amend, Thomas F. Jr.
# Morton, George P
# Petazzoni, Maxime
# Cashman, Julie
# Newman, Joy
# Snider, Blake
# Pinkerton, Tom
# Hingle, Laura
# Turpin, Rob
# Forbes, Jim
# Marincic, Tommy
# King, Ronan P.
# Quinn, Kevin P
# Gorowski, Greg
# Lawton, Adam
# Lavoie, Vincent
# Maylone, Bethany
# Robbins, Amy
# Shea, Carolyn
# Bonvillain, Frederic X
# Kofoed, Niels
# Margarella, Carolina
# Wellford, Jan H
# George, Sue
# Dolley, Amy
# Anis, Michael
# Street, Holly
# Hughes, Samantha E.
# Roberts, Duncan
# Hoogendoorn, Thomas J
# Vitalo, Antonia G
# Cronin, Neil J.
# Yarbor, Lee Ann
# Held, Michael S
# Callaghan, James
# Burnett, Lynn
# Barr, Michael P.
# Homeyer, Thomas F.
# Almeida, Jennifer M
# St. Amant, Robert
# Kresky-Griffin, Lisa A
# Murphy, Douglas
# Bauckman, Mark
# Callahan, Kevin M.
# Padula, David
# Robinson, Knox
# Hau, Vincent
# McCarthy, Megan P.
# Brosilow, Michael
# Hardy, Jon
# Wilson, Ed
# Reisenauer, Matthew
# Hoaglin, Bob
# Gange, Wilmer
# McQuaid, Jenn
# Barron, Chris
# Hrybyk, Brian
# Keibel, Martin
# Weibel, Kim M
# Sweeney, Jesse
# Pedersen, Kristen
# Dubeau, France
# Hahn, Mimi
# Peralta Ramirez, Gustavo Adolfo
# Fletcher, Kimberly A.
# Li, Ailin
# Ross, Stuart E
# Greene, Ben
# Dibartolomeo, Joseph
# Green, Addie
# Mack, Don
# Gens, Frank
# Jasmin, Bambi H
# Yoshida, Junichi
# Smith, Charlie
# Swanson, Erik
# Tierney, Heather A.
# Layton, Scott F
# Reiley, Sally A
# Zabukovec, Randy
# Torres, Sergio
# Davenport, David C
# Catoline, John
# Chercuitte, Louise
# Mulligan, Brian Patrick
# Kalmar, Kimberly A
# Vasconcelos, Lynn
# Holmen, David
# Lee, Robert J
# Aron, Narcis
# Yum, Kenny
# Nate, Steve
# Roark, Ken
# Lavallee, Richard
# Cassidy, Chris
# Fluerasu, Andrei
# Gervais, Charles K
# Okon, John A.
# Mooney, Danny B
# Hagan, John
# Kurosawa, Fuminobu
# Walk, Gary
# Gallagher, Robert
# Carlone, Mirella
# Allen, Mac
# Hawk, Shawn C
# Simpson, David
# Murray, Jennifer
# Read-Brown, Ken
# Rochette, Susie
# Gordyan, Ryan
# Madden, Michael
# Drout, Jonathan
# O'Brien, Felicia
# Salenetri, Nikki
# Smith, Suzanne
# Barranti, Pete
# Dery, Normand
# Straw, Keith
# Cheong, Tony
# Graham, Nolan R
# Ryan, Tina
# Melisi, Michael N. II
# Barrett, Maryn
# Loens, George L.
# Ortega, Ricardo
# Duggan, Margaret
# Roebal, Bruce A
# Van Buren, Roy F.
# Voghel, Louise
# Anchondo, Joseph
# Reny, Steven A.
# Parmigiani, Giovanni
# Johnson, Samantha
# Debrah-Dwamena, Kwabena III
# Jacobson, Gwen R
# Holland, Andy
# Kinnaman, Matt
# Wilder, Bobby
# Mathison, Holly
# Bond, Robert J.
# Gates, Kate L.
# Richardson, Craig I
# Meier, David
# Tydlaska, Shawn
# Kwon, Yi-Joo
# Casady, Ilana
# Shumko, Sergey
# Waldron, Kathryn A.
# Nguyen, Leann
# Daly, Siobhan D.
# Scott, Elizabeth
# Jaworski, Kathleen
# Melby, Eric
# Owen, Elizabeth A.
# Smith, Cameron A.
# Kato, Mami
# Imhoff, Ethan
# Morrissey, Brendan A.
# O'Brien, Daniel
# Davi, Michael J
# Smith, Terence J.
# Stone, Jim
# Muehlschlegel, Danny
# Ryan, Ann M.
# Kado, John
# Soroko, Jay M.
# Lautzenheiser, Daniel
# Pulling, Phyllis A
# Duvall, Harry
# Bourg, Cory P
# Bottillo, Antonio
# Liu-Stenger, Su-Nin
# Kerr, Barbara R
# Langevin, William J.
# Dever, Shaun R
# Bouaichi, Abdel
# Coyne, Brian M
# Sypek, Steve
# Stieber, Allan
# Leitz, Aya
# Martin, Phil
# Kmack, Kristin M
# Buciak, Mark J.
# Trotter, Paul
# Ross, Andrew
# Shur, Kenneth L.
# Kwon, Young-Sook S.
# Bolullo, Olivier
# Blendell, Beth
# Constable, Chris
# Blackwell, Eric
# Kwon, Deukwoo
# Iwasa, Yasuo
# Taylor, Steve
# Ospina, Jorge
# Rogers, Tye
# Hall, Sally
# Adler, Robyn
# Phan, Howie
# Milton, Michelle
# Stone, Lisa
# Clapp, Meghan K.
# Hall, Mary E.
# Cuadra, Bernardo
# Wilson, Lisa J.
# Larosa, Mark
# Yendt, Robert B
# Thiel, Rita
# Russell, Aaron
# Doyle, Kevin M.
# Deroian, Rhea
# Bauman, Sheridan H
# Vegas, Julia
# Deschenes-Desmond, Caitlin
# Machowski, Audrey
# Malley, Rita E.
# Gennaro, Erica
# Maina, Stanley
# Knott, Mark
# Price, Tim
# Call, Gloria
# Bennett, Elizabeth
# Tymchak, Pam
# Tanner, Martin
# Boyle, Joseph C
# Barana, Victoria
# Delaney, Debra
# Kanaracus, Stavros
# Jarrin, Robert
# Driscoll, James J.
# Barcon, Carlos
# Madej, Robert
# Cunningham, Lori A.
# Venzor, Omar
# Damiano, Robert P
# Jefferson, Michael
# Zeldin, Jessica
# Aitken, Kyle
# Lefebvre, Francois
# Ciampa, Kathleen M.
# Maru, Seiichiro
# Moore, Sean
# Matarese, Joseph
# Gisolfi, Tanya
# Sikora, Joseph
# Timmerman, Luke
# Erickson, Anders J
# Mitchell, Christine J.
# Perez, Christian
# Abdallah, Michael A
# Sutton, Dylan P
# Ferguson, J Daniel
# Temple, Brian
# Levy, Frank N.
# Gouge, Paul E
# Bolduc, Sharon
# Willford, Alan
# Villiano, Julie
# Swenson, Will
# Reed, Erik
# Fish, Michael J
# Janssen, Avi
# Frechette, Rebecca J.
# Jensen, Roger
# Vath, Steven
# Hribar, Madelyn C
# Miller, Gerald W
# Pell, Mary Anne
# Spry, Jeremy
# Fitzgerald, Shawn
# Gretzky, Kayla R.
# Wade, Michelle M.
# Fitzpatrick, Jim
# Geissinger, John D
# Carey, Aaron
# Cummans, Joann
# Carr, Lucas S.
# Prince, Kellie A.
# Ganzi, Rick
# Willcox, Joanne
# Abitbol, Matthew
# Wetter, Thomas J
# Otani, Mika
# Kells, Doug
# Rossi, Adam
# Tarleton, Ken
# Egan, Alison
# McLucas, Doug
# Benros, John E.
# Scott, Rick
# Gipson, Clay
# Sasaki, Yoshiaki
# Micue, Tracey M.
# Zarling, Zac
# Lancaster, Christopher
# Angelillo, Frank Jr.
# Paradis, Rejean
# Massicotte, Michel
# Bonilla-Gomez, Minor
# Beaudry, Odette
# Woytowicz, Katie
# Murphy, Kristan M.
# Christmas, David A.
# List, Jay
# Greer, Michelle
# Granski, Megan
# Gregory, Sherry L
# Smith, Larry
# Alexander, Jeff
# Garvey, Thomas G IV
# Ollinger, Patrick
# Doherty, George F III
# Underdown, Garrett B
# Morehart, James H.
# Hagan, Stephen
# Morin, Brian J
# Moore, David
# Mixon, Ki
# Peltzer, James
# Lipcsei, Violeta
# Pieroway, Mathew R.
# Lavery, Sheila A
# Olesky, Sarah E
# Votapka, Todd E
# Plough, John J.
# Spence, Jessica L.
# Dupere, Sally
# Kinneman, Tom
# O'Connor, Margaret
# Proulx, Lise
# Kroupa, Bob
# Reidy, Dennis J.
# Samson, Bruno
# Barnette, Alan
# Wang, Xiao
# Simard, Chantal
# Johnson, Eric C.
# Salerno, Matthew G
# Laster, Daniel
# Roulier, Sebastien
# Morris, Anna L
# Maillette, Francois
# Morris, Megan M
# Greene, John K.
# Ottaviano, Gerard J.
# Luthman, Linda J.
# Pizzi, Becca
# Garvey, Julie
# Sansonetti, Danielle
# Petrovic, Victor
# Kokta, Victor
# Switt, Angela H
# Ladka, Terri M
# Ingold, Karen
# Favuzza, Robert J.
# Beatty, Paula
# Debruin, David
# Nusblat, Michael
# Marks, Lisa
# Townsend, Susan M
# Doherty, Caitlin E.
# Huber, Casey
# Rosenblum, Marc A.
# Winkelman, Laurie A
# Zappen, Rich
# Trinh, Charlene
# Zhang, Jun
# Landry, Paul
# Letourneau, Claude
# Poirier, Isabelle
# Godale, Mark
# Ohara, Chip
# Lombardi, Christopher
# Huyffer, Eric
# Timmons, Patrick M.
# Petrov, Simeon
# Underwood, Daniel
# Burke, Donald
# Kraus, William E
# Ashcraft, John L Jr.
# Montigue, Tre
# Lynch, Damien P.
# Crotteau, Charles A
# Kralj, Heather
# Sharp, Ray
# Harstad, Derek M
# Campione, Diane M
# Llana, Carmen
# Sweny, Andrea
# Luc, Ryan
# Jones, Matt F
# Cannon, Calleen A
# Groff, Adam C
# Burrows, Stephen
# Pore, Thomas
# Chow, Andrew
# Swansey, Laurie A.
# Ross, Gayle
# Rose, Mikayla
# Duhaime, Spencer
# Coyne, Rick
# Chen, Marilyn
# Bell, Susan
# Spinelli, Camila
# Manser, Erich
# Taylor, Julia
# Hoffman, Jennifer
# Ubersax, Jeffery D
# Geary, Timothy F.
# Proulx, Ryan
# Powell, Neil
# Burns, Shawn
# Metzger, Peter T II
# Juppe, Michael
# Williams, Ray K.
# Bell, Patrick
# Peebles, James T
# Rivard, Alain
# Cap, Ludovit S.
# Selin, Bruce
# Altman, Lisa
# Dorsky, Lauren
# Smalley, Steve
# Coyne, David A.
# Pinori, Mauro
# Atwater, Beau
# Glaser, Thomas A
# Kotaska, Bill
# McGuirk, Erin K.
# Kropelnicki, Jesse
# Magnussen, Jon M. Jr.
# Allie, Douglas M.
# Kronback, Eric
# Schmitz, Jake
# Graham, Matthew R.
# Rankin, Greg
# Wallach, Jon
# Circosta, Gary F.
# Longo, John
# Wedding, John M
# Willard, Lindsay A.
# Smith, Sean
# Fehr, Jake
# Lass, Barry
# Strider, Scott K.
# Gardner, Rachel B
# Jaremback, Kristen
# Abanses, Jolene C
# Fisher, James A
# Taylor, Ray
# Policelli, Neil
# Feda, Jessica
# Kharitonov, Tony
# Wang, Katharina
# Rooney, Sean A.
# McDermott, Jack T.
# Boersma, Aaron M
# Schwartzbard, Aaron
# Kinch, Jared
# Bretz, Virgil
# Busch, Joni
# Kornitz, Roni
# Richards, Jeannette
# Ashby, Robert S
# Phemister, Jordan
# Ringheiser, Karen
# Seifert, Eric
# Smith, Bradley T
# Breau, Marcelle
# Balistreri, Theodore
# McCarthy, Michael
# Martin, Barbara
# Ayastuy, Carolina
# Staveski, Mark
# Dunn, Wally
# Oh, Keon
# Kane, Joe
# Sullivan-Inglis, Sheila
# Lilley, Sean
# Varga, Astrid
# Ryan, Jennifer
# Ellis, Ryan
# Anderson, Donna M
# Baumberger, Marybeth
# Ritzman, Stacy
# Lee, Jason
# Ramirez, Elizabeth
# Cooney, Elizabeth
# Newcomer, Walter W
# Gao, Sihai
# Savard, Justin
# Mattson, Daniel
# Kato, Yukiko
# Flatow, Kirk
# Sanders, Jeremy
# Nevitt, Dave
# Hagin, John
# Rosenberg-Wohl, Jacob
# VanderZand, Bob
# Bardeesy, Rami
# Kalkhurst Burbo, Kirsten
# Hernandez-Pinzon, Ricardo
# Williams, James E.
# Chng, Peter
# Losee, Todd
# Fernandez, Olga
# Haselden, Amanda L
# Garneau, Martin
# Baroffio, Bryan
# Damenti, Nicholas
# Forrester, Nichola P.
# Goldberg, Ellen S.
# Muroi, Chiemi
# Tang, Jingjing
# Shen, Yefeng
# Soden, Patricia
# Smith, Donna Hayashi
# Flaggert, Alison
# McGonagle, Neil C.
# Fukuchi, Yoko
# Beggrow, Anthony D
# Darbinian, Silva
# Lizak, Marisa A
# Bennewitz, Lauren
# Bain, Christopher
# Csuy, Jeff
# Newland, Ernie
# Osterlind, Meghan S.
# Martin, Michele E.
# Powers, Christi
# Brown, Todd
# Fox, Laura F
# Chuu, Wenmin
# Durant-Young, Zaire
# Seney, Matt
# Daugherty, Eric
# Peddy, Christine
# Miller, Jennifer
# Corbey, Gerald T. Jr.
# Barrett, John S.
# Mackay, Cole
# Pon-Brown, Kay
# Gerlach, Christopher P
# Cincola, Mike
# Mordis, Barry D.
# Rankin, Chris
# Mcadoo, Susan
# Silva, Ryan J.
# Fishman, Gretchen
# Welby, Bob
# Kutner, Robin
# Rodriguez, George A.
# Spencer, David
# Ames, Anthony J
# Killius, Krista
# Traffie, Nels
# Coache, Vaunette
# Dallaire, John
# Shane, Michael
# Clingerman, Yuri
# Platais, Imants
# Laurent, Denise
# Haggerty, Kevin
# Crookshank, Patti
# Venick, Robin
# Young, Riya
# Edge, Norma
# Weber, Joel B
# Lombardo, David J
# Dekornfeld, Tom
# Okon, Valerie G.
# Song, Kun
# Westjohn, Yale G
# Revenis, Bradley D
# Alperin, Daniel S.
# Shapiro, Julie-Ann
# Rohrbeck, Stacey K
# Foy, Ghislain
# Delaney, Jennifer
# Gardner, Jo Ellen
# Lin, Ashley
# Burkett, Jenn
# Fortier, Yannick
# Tigani, Michael
# Imai, Christopher A
# Lay, Sharon E
# Fredsall, Tyler
# Karas, Tina M.
# Feinhaus, Dima
# Johnson, David
# Townsend, George D.
# Lechtenberg, Sandy
# Tsoucas, Pantelis
# White, Jessica
# Kennedy, Katherine C.
# Masterson, Stephen G.
# Johnston, Christoffer
# Chirdon, Jeff
# Johnston, Lisa
# Angel, James
# Quiros, Christine
# Hopley, Nick
# Kirkwood, Meghan
# Otieno, Megan
# Stenta, Meredith
# Bosco, Michelle
# Kosina, Bill
# Lysniak, Ula
# Roth, Jeff
# Donaghy, Roger
# Sabin, Jenn
# Fennon, Myles
# Kemp, Lora J
# Winter, Carol D
# Shrum, Ryan
# Axelsen, Bill
# Geesler, John
# Bojczuk, Paul
# Cavasinni, Joe E
# Gallardo, Lupe
# Latimore, Robert T
# Kennedy, Jake
# Baumgartner, Andrea
# Hevey, Debra L
# Rancour, Judith
# Anair, Raymond M.
# Herring, Jennifer
# Young, Melissa
# Ahmim, Youcef
# Marshall, Wendy
# Melim, Joseph P
# Eck, Peggy
# Salim, Jill S
# Brooks, Daniel
# Seibert, Monique
# Russey, Daniel
# Eggers, Thomas S.
# Wirtanen, David
# Turnbull, Ture R.
# Putt, Tammy
# Pepe, Amy E.
# Seamon, Walter
# Weeks, Megan K.
# Dunn, Alyson
# Feil, Justin
# Varner, Alexander
# Sample, Jennifer
# Huyffer, Paul S
# Tassini, Sharon J.
# Roberge, Melanie
# Gile, David
# Popa, Cristian
# Whiting, Patricia
# Briggs, Sadie S.
# Godale, Stephen
# Santa-Ana, Cuau R
# Gilpin, John W.
# Bauernfeind, Christopher
# Ackerman, Rachel E
# Johnson, John D.
# Moreno, Cristy
# Milligan, Gary K
# Hawthorn, James
# Hobin, Michelle C.
# Tian, Tongsheng
# Downs, Deborah
# Dunfey, Brian
# Mangold, Zandy
# Hara, Hiromi
# Holmes, Lindsay
# Hodges, Barbara
# Schmidt, Sandra J
# Berlin, Daniel
# Dolan, Robert T
# Oza, Amit
# Wheatcroft, Simon P.
# Ponsard, Alain
# Crawford, Kathleen M.
# Bull, Debi J
# Hewitt, Lee
# Brown, Morgan
# Jennings, Hannah
# Vachon, Marilyn
# Hehir, Carolyn
# Matthews, Thomas W III
# Manion, Linda
# Kawashima, Jun
# Murray, Dennis C.
# Baxter, Robert
# Hilles, Diza M
# Negoro, Yukihiko
# Fraser, Kyle
# Flanigan, James A.
# Noonan, Joe
# Ogino, Dennis
# Wallman, Barry D.
# Brejcha, Barrie L.
# Hodge, Emily
# Gay, Chari M
# Tierney, Leanne S.
# Bush, Lee Ann
# Pankratz, Shelby
# Nowacki, Laura
# Utakis, Donna
# Goldberg, Samuel L
# Hebert, Diane
# Bradley, Sara
# Knapp, Robert C.
# Fogel, Lori
# Spann-Ly, Loc
# Jones, Chris S
# Rose, Katie
# Macbeath, Gavin
# Teichman, Joel
# Glaser, Jeff
# Kwok, Margaret
# Clappsy, Andrea
# Doan, James K II
# Legresley, Daniel
# Kauffman, William L. Jr.
# Close, Lindsay M
# Stadolnik, Michael
# Beaulieu, Patrice
# Reilly, Karen M
# Firestone, Lisa
# Cooper, Char
# Jouar, Ahmed
# Strelzik Wiessmann, Carly
# Tom, Jennifer
# Votteler, Jeffrey
# Clark, Bette
# Desantis, Andrea
# Maloney, Clyde A.
# Guthals, Nathaniel
# Heitzwebel, Tim
# Surrette, Tom
# Crous, Martin
# Ogle, Cat
# Leippert, Yvonne
# Davidson, Terry
# Shannon, Colleen M.
# Galvez, Daniel
# Barrett, Patricia
# Perzyk, Karen
# Cormier, Gilles
# Mastrianni, James
# Daley, Brenda
# Piepmeier, Christy
# Darnell, Jennifer
# Beyrak, Yakov
# Menzies, Nicolas
# Lydstone, Haley A
# Zobler, Marian
# Madden, Brian J.
# Wallingford, Dave
# Labelle, Bernard
# Maxfield, Cory W
# Hellman, Joanna
# Dodds, Richard
# Buenting, Mike
# Dean, Tripp
# Vogt, Kris
# Antonson, Dave
# Reed, Craig S
# Skokos, Callie
# Aufdencamp, Adam L
# Febres-Cordero, Rafael A.
# Coppinger, Kimberly A.
# Walsh, Patrick D
# Sanchez, Margaret
# Sandefur, Patrick
# Anderson, Mark
# Pyasta, Roman
# Duca, Matthew A.
# Rork, Matthew J.
# Harrison, Bob
# Reardon, Paul R. Jr.
# Resnikoff, Ted
# Rusch, Dorothy
# Yu, Michael
# Dettmering, Brett A
# Meier, Amy
# Dellett, Steve
# Drohan, Colleen E.
# Collier, Jeff
# Levan, Emily
# Megran, Jack
# Stech, Susanne
# Chen, Sophia
# Gabris, Stephen
# Schulten, Chris
# Phillips, Scott B.
# McMillin, Alex W.
# Purks, Susan A
# Kuehler, Jon
# Wright, Kathleen F.
# Tremblay, Yanick
# Faught, Jody
# Duke, Nancy M
# Bruce, Megan
# Abber, Tracy
# Lee-Callaghan, Heather
# Lepper, Andrew
# Siciliano, Robert
# Burnham, Stephanie L.
# Malkowski, Eric
# Houle, Michel
# Gersitz, Lorraine
# Ludington, Johannah
# McCloud, James M.
# Beauchamp, Bret
# Alexander, Jake
# Chase, Kimberlee A
# Larsen, Kay E
# Varallo, Vince
# Green, Janet E
# Damveld, Mark
# Stone, Tom
# Taylor, Deb
# Stahl, Sara
# Dugan, Daniel S.
# Guth, Michael
# Remsburg, Cade K
# Chang, Jennifer
# Klarich, Lee
# Gentile, Michael
# Okamura, Toshio
# Westcott, Christine
# Tabata, Yosuke
# Crowe, William D
# Jobin, Dominique
# Wrigley, Ryan
# Carmona, Paul D
# Demchko, Caitrin
# Sweeney, Andrew E.
# Flaks, Erica
# Barnhart, Gregory S
# Korir, Wesley
# Treleven, Angela N.
# Lim, Moo S.
# Russell, Christopher J.
# Hawkins, Zach
# Kemble, Traci A
# Hidaka, Yuichiro
# Weigel, Lindsay
# Satterlee, Linnae
# Jayson, Stephen
# Lamb, Robert C. Jr.
# Garza, Gabriel
# Furukawa, Toshiharu
# Goloboy, Lauren F.
# Bridges, Jeremy T
# Alonso, Laura C
# Croft, Darrell G
# Falb, Eliezer
# Rigitano, Vincenzo
# Lubetsky, Caryn
# McCarron, Bob
# Walton, Brenda
# Kaye, Eric
# Cote, Benoit
# Faucher, Pierre
# Rojas, Pedro
# Curiel, Tyler
# Cohen, Ilana
# Kelly, Melinda
# Walker, Eric A
# Druke, Nancy
# Hamilton, John
# Dalton, Jackie
# Ten, Cheng
# Edwards, Bill S Jr.
# Dean, Kevin
# Pulli, Michael
# Chivasa, Mufaro
# Bridges, Gene
# Plakas, Timothy
# Spencer, Nathan
# Lavalle, David
# Yung, Betty
# Chavez, Roberto
# Stephen, Laura C
# Battaglino, Peter
# Benardete, Steven
# Togami, Katsuhiro
# Cosner, Cathy
# Cotrone, Michael J.
# Ray, Maria
# Frobeen, Daniel
# Yi, Kwang-Jae
# Kishimoto, Yasushi
# Nolan, Michael A.
# Mantell, Joanna
# Schmickel, Joanna
# Salazar, Eli
# Paulin, Michael
# MacDonald, Jesse
# Van'T Veer, Erik
# Revanna, Krupakar
# Dimon, Kelli
# Gaffney, Lukas
# Bourassa, Pierre
# Hammond, Robert
# Provencher, Dany
# Pezzati, Patrick
# Warriner, Lawrence
# Hughes, Bettina
# Young, Michael
# Taylor, Gregory A
# Mercier, Christian
# Elsner, Merlin
# Casterline, John
# Harden, Steven
# Fukuchi, Yoshinori
# Williams, Michael
# Fudge, Teresa
# Parker, Jill
# Walhovd, Kristine B.
# Woods, Tom
# Magee, Josie
# Marshall, Christopher J.
# Di Lisio, Michael
# Hatathli, Thomas
# Holahan, Sandra L
# Yang, Shizhong
# Brewer, Rosemary W.
# Volberding, Wes
# Bosmann, Bill
# Reynolds, Tim
# Bates, Renee
# Gamez, Arturo
# Carthy, Damien P.
# Zeigler, Heather
# Resney, Romney
# Nieto, Veronica
# Deba, Buzunesh
# Terracina, Joe
# Oelberg, David A
# Snyder, Christina M.
# Dale, Jennifer
# Floss, Peter
# Kalnay, Boyd
# Lemoine, Gregory S
# Izgarjan, Robert
# Ruiz De La Pena Hiriart, Melissa
# Turner, Louise A
# Desgagnes, Cathy
# Boyd, Caleb
# Salmeri, Jim
# Dunne, Alexandra W.
# Chazen, Claire
# Tannascoli, David
# Taylor, Trent A
# Cavatorta, Jason
# Harding, Jim
# Michel, Kyndal
# Pickett, Paul M.
# Rosati, Hasarun
# Goulet, Roger
# Fair, Stephen
# Harris, Charles W Jr.
# Meninger, Daniel T.
# Bolullo, Phil
# Polansky, Francis
# Kidane, Argaw
# Perez, Tammy
# Herbolsheimer, John A
# Hymovitz, Marc C.
# Adachi, Shinsuke
# Mullen, Beth R
# Howe, Karen
# Nix, Christopher J.
# Rose, Pamela
# Sheppard, Judy
# Beiswanger, Lynn
# Spooner, David
# Walsh, Lauren D.
# Ross, Jerome
# Rock, Christie
# Gordon, Michael
# Flanagan, Sean
# Agar, Courtney M.
# Picklesimer, Gregory
# Tabata, Yasuhiro
# Jicha, Tina L
# Ream, Devin W.
# O'Connor, Linda Marie
# Bryant, Andrew V.
# Arsenault, Michael
# Craven, Joseph P. III
# Smith, Paul E Jr.
# Anaya, Ignacio
# Riley, Michael A
# Galvin, Mike V
# Whiteman, Mara
# Crowe, Heather
# Knoop, Lindsay
# Beittoei, Alireza
# Santoro, David P.
# Leitz, Karl
# Case, Lauren
# Blaszynski, Robert S
# Capriccioso, Christina
# Awanya, Francis A
# Rusiecki, Amy
# Colombo, Michael J
# Medina, Moises
# Russell, Sue R
# Marlar, Drew
# Benz, Brad
# Koyano, Yasuyuki
# Schwartz, Derek N.
# Hamrock, Michael G.
# Strohschein, Katie
# Sullivan, Molly F.
# Adler, Danielle E.
# Lawrence, Robert L.
# Lundin, Scott C.
# Collins, Terrance M
# Miller, Paul E
# Marsh, William P
# McGrane, Michael
# Kutlin, Andrei
# Bachicha, William S.
# Cherewatti, Jack
# Rancourt, Bernard
# Liuzzo, Lauren
# Shipp, Trey
# Sullivan, Melodie
# Craft Ahrens, Amy
# Sturm, Sabine
# Cote, Pierre
# McNally, Kathleen E.
# Kochowiec, Alexy
# Le Jamtel, Jerome
# Esch, Linda A
# Zhu, Gaofeng
# Daly, Daniel P.
# Pimental, Jennifer A.
# Myers, Anne Hunter
# Phillips, Ray T.
# Lannon, Kimberly A.
# Devaney, Rick
# Nijensohn, Lynda A.
# Goetsch, Otto
# Morgan, Heather L
# Hrabchak, Rick
# Macaluso, Catherine
# Peckiconis, Stephen
# Reid, Marc
# Hsia, Brian W.
# Hibbs, Stephen
# Ash, Alan
# Jo, Yoshiko
# Brown, Barb E
# Wilson, Andrea Z.
# Stader, Scott A.
# Shaw, Carolyn
# Callahan, Patrick M.
# Cattarin, Gary
# Hill, Daina
# Miller, Glen
# Lynch, Molly T.
# Pasten, Alejandro
# Ehredt, Michael
# Christoni, Timothy
# Rivera, Jose W.
# Leboeuf, Nicole R.
# Patriarca, Ryan
# Kinsella, Michelle L.
# Corsaro, Nancy
# Klausner, Daniel H
# Gerbino, Amy
# Goldberg, Lew
# Stomiany, Michael T
# Dong, Baoping
# Pirrung, Roy
# Donabedian, Christine A
# Feaster, Jenifer H.
# Schahet, Greg
# Tesfamariam, Keleta
# Cotter, Bill
# Parks, Tori
# Honrath, Jerod
# Maybach, Jeff
# Starbuck, Ryan
# Sherman, Michelle L
# Kandt, Rebecca
# Shafer, Chris
# Bezkorovainy, Hordiy
# Herman, Russell W
# Sprieser, Steven
# Haggerty, Sean R.
# Constantino, David
# Sukstorf, Simon
# Gilmartin, Kevin M.
# Matusik, Danielle
# Peterson, John R.
# Hewson, Brooke
# Glass, Rhonda
# Micros, Deanna
# Basta, Bill
# Trottier, Isabelle
# Merrick, Ken
# Erickson, Bjorn E

# %% [markdown]
# - Who are the winners of each year?

# %%
winners = []
for year in df['Year'].unique():
    winner = df.loc[(df['Year'] == year) & (df['Overall'] == 1), 'Name'].values[0]
    winners.append(winner)

# Print winners and years side by side
for i in range(len(winners)):
    print(f"{winners[i]} - {df['Year'].unique()[i]}")
# Out:
# Desisa, Lelisa - 2015
# Hayle, Lemi Berhanu - 2016
# Kirui, Geoffrey - 2017

# %% [markdown]
# - Who is the oldest runner of each gender, out of these three years?

# %%
# Group the data by gender
grouped_data = df.groupby('M/F')

# Loop through each group
for gender, group in grouped_data:
    # Find the row with the largest age in the group
    max_age_row = group[group['Age'] == group['Age'].max()]
    # Print the name with the largest age in the group
    print("Gender:", gender)
    print("Name with the largest age:", max_age_row['Name'].values[0])
    print("Age:", max_age_row['Age'].values[0])
    print("--------------------")
# Out:
# Gender: F
# Name with the largest age: Beiers, Katherine
# Age: 84
# --------------------
# Gender: M
# Name with the largest age: Wilson, Harold
# Age: 83
# --------------------

# %% [markdown]
# ### Data Engineering
#
# We can create some new features based on our data. One feature we can add is the division name.

# %%
age_group_mapping = {
    'M18-39': ['M', 18, 39],
    'M40-44': ['M', 40, 44],
    'M45-49': ['M', 45, 49],
    'M50-54': ['M', 50, 54],
    'M55-59': ['M', 55, 59],
    'M60-64': ['M', 60, 64],
    'M65-69': ['M', 65, 69],
    'M70-74': ['M', 70, 74],
    'M75-79': ['M', 75, 79],
    'M80+': ['M', 80, float('inf')],
    'F18-39': ['F', 18, 39],
    'F40-44': ['F', 40, 44],
    'F45-49': ['F', 45, 49],
    'F50-54': ['F', 50, 54],
    'F55-59': ['F', 55, 59],
    'F60-64': ['F', 60, 64],
    'F65-69': ['F', 65, 69],
    'F70-74': ['F', 70, 74],
    'F75-79': ['F', 75, 79],
    'F80+': ['F', 80, float('inf')]
}


# Create an empty column for Age/Gender group
df['Division Name'] = ''

# Iterate over each row in the DataFrame
for index, row in df.iterrows():
    gender = row['M/F']
    age = row['Age']
    
    # Find the matching age group in the mapping
    for key, value in age_group_mapping.items():
        if value[0] == gender and value[1] <= age <= value[2]:
            df.at[index, 'Division Name'] = key
            break

# %% [markdown]
# Note: Similar to `loc`, in that both provide label-based lookups. Use at if you only need to get or set a single value in a DataFrame or Series.
#
# Food of thought: why are we not simply using brackets?
# Hint: https://pandas.pydata.org/docs/user_guide/indexing.html#indexing-basics-get-value

# %% [markdown]
# ### Data Visualization
#
# #### Histogram: Age distributions

# %%
import matplotlib.pyplot as plt

# Create a histogram of age distribution
plt.hist(data['Age'], bins=20, edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution')
plt.show()

# %% [markdown]
# #### Scatter Plot with Trend Line: Finish Time vs Age

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create a scatter plot of finish time vs. age
plt.scatter(df['Age'], df['Official Time'] / 3600)
plt.xlabel('Age')
plt.ylabel('Finish Time (hours)')
plt.title('Finish Time vs. Age')

# Add trend line
z = np.polyfit(df['Age'], df['Official Time'] / 3600, 1)
p = np.poly1d(z)
plt.plot(df['Age'], p(df['Age']), "r--")

plt.show()

# %% [markdown]
# #### Box Plot: Division Vs Finish Time

# %%
import seaborn as sns

# Create a box plot of finish time by gender
df['Official Time (Hr)']=df['Official Time']/3600
sns.boxplot(x='Division Name', y='Official Time (Hr)', data=df)
plt.xlabel('Division')
plt.ylabel('Finish Time')
plt.title('Finish Time by Division')
plt.rcParams['figure.figsize'] = [12, 8]
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### Line chart: Does Top Runners stays top for the whole race?
#
# For the fastest 10 runners in 2015, create a line chart based on their splits.

# %%
df_2015 = df[df['Year'] == 2015].sort_values('Official Time')

# Select the top 10 runners
top_10 = df_2015.head(10)

for index, row in top_10.iterrows():
    plt.plot(row[['5K', '10K', '15K', '20K', 'Half', '25K', '30K', '35K', '40K', 'Official Time']], label=row['Name'])

plt.xlabel('Distance')
plt.ylabel('Time (Seconds)')
plt.title('Top 10 Runners in 2015')
plt.legend()
plt.show()

# %% [markdown]
# References:
#
# [1] [https://online.hbs.edu/blog/post/data-wrangling](https://online.hbs.edu/blog/post/data-wrangling)
#
# [2] [https://www.tomasbeuzen.com/python-programming-for-data-science/](https://www.tomasbeuzen.com/python-programming-for-data-science/)
#
# [3] [https://www.kaggle.com/learn/data-cleaning](https://www.kaggle.com/learn/data-cleaning)
#
# [4] [Pandas Documentation](https://pandas.pydata.org/docs/user_guide/index.html)
